# %%
import pandas as pd
import numpy as np

# Note: Dealer_No had a trailing space.  Rename column names to something more readable
colnames = ['Car_id', 'Date', 'Customer Name', 'Gender', 'Annual Income', 'Dealer Name', 'Company', 'Model', 'Engine', 'Transmission','Color', 'Price', 'Dealer_No', 'Body Style', 'Phone', 'Dealer Region']

# Load the data
carSales = pd.read_csv("datasets/carSales.csv", header=0, names=colnames)
carSales
#carSales[carSales.columns] = carSales.apply(lambda x: x.str.strip())
# Out:
#              Car_id        Date Customer Name  Gender  Annual Income  \
# 0      C_CND_000001    1/2/2022     Geraldine    Male          13500
# 1      C_CND_000002    1/2/2022           Gia    Male        1480000
# 2      C_CND_000003    1/2/2022        Gianna    Male        1035000
# 3      C_CND_000004    1/2/2022       Giselle    Male          13500
# 4      C_CND_000005    1/2/2022         Grace    Male        1465000
# ...             ...         ...           ...     ...            ...
# 23901  C_CND_023902  12/31/2023        Martin    Male          13500
# 23902  C_CND_023903  12/31/2023         Jimmy  Female         900000
# 23903  C_CND_023904  12/31/2023          Emma    Male         705000
# 23904  C_CND_023905  12/31/2023      Victoire    Male          13500
# 23905  C_CND_023906  12/31/2023       Donovan    Male        1225000
#
#                                Dealer Name    Company       Model  \
# 0      Buddy Storbeck's Diesel Service Inc       Ford  Expedition
# 1                         C & M Motors Inc      Dodge     Durango
# 2                              Capitol KIA   Cadillac    Eldorado
# 3                   Chrysler of Tri-Cities     Toyota      Celica
# 4                        Chrysler Plymouth      Acura          TL
# ...                                    ...        ...         ...
# 23901                     C & M Motors Inc   Plymouth     Voyager
# 23902       Ryder Truck Rental and Leasing  Chevrolet       Prizm
# 23903               Chrysler of Tri-Cities        BMW        328i
# 23904                    Chrysler Plymouth  Chevrolet       Metro
# 23905                      Pars Auto Sales      Lexus       ES300
#
#                           Engine Transmission       Color  Price   Dealer_No  \
# 0      DoubleÂ Overhead Camshaft         Auto       Black  26000  06457-3834
# 1      DoubleÂ Overhead Camshaft         Auto       Black  19000  60504-7114
# 2              Overhead Camshaft       Manual         Red  31500  38701-8047
# 3              Overhead Camshaft       Manual  Pale White  14000  99301-3882
# 4      DoubleÂ Overhead Camshaft         Auto         Red  24500  53546-9427
# ...                          ...          ...         ...    ...         ...
# 23901          Overhead Camshaft       Manual         Red  12000  60504-7114
# 23902  DoubleÂ Overhead Camshaft         Auto       Black  16000  06457-3834
# 23903          Overhead Camshaft       Manual         Red  21000  99301-3882
# 23904  DoubleÂ Overhead Camshaft         Auto       Black  31000  53546-9427
# 23905  DoubleÂ Overhead Camshaft         Auto  Pale White  27500  38701-8047
#
#       Body Style    Phone Dealer Region
# 0            SUV  8264678    Middletown
# 1            SUV  6848189        Aurora
# 2      Passenger  7298798    Greenville
# 3            SUV  6257557         Pasco
# 4      Hatchback  7081483    Janesville
# ...          ...      ...           ...
# 23901  Passenger  8583598         Pasco
# 23902    Hardtop  7914229    Middletown
# 23903      Sedan  7659127    Scottsdale
# 23904  Passenger  6030764        Austin
# 23905    Hardtop  7020564    Middletown
#
# [23906 rows x 16 columns]

# %%
carSales.shape

carSales.head(30)
# Out:
#           Car_id      Date Customer Name  Gender  Annual Income  \
# 0   C_CND_000001  1/2/2022     Geraldine    Male          13500
# 1   C_CND_000002  1/2/2022           Gia    Male        1480000
# 2   C_CND_000003  1/2/2022        Gianna    Male        1035000
# 3   C_CND_000004  1/2/2022       Giselle    Male          13500
# 4   C_CND_000005  1/2/2022         Grace    Male        1465000
# 5   C_CND_000006  1/2/2022     Guadalupe    Male         850000
# 6   C_CND_000007  1/2/2022        Hailey    Male        1600000
# 7   C_CND_000008  1/2/2022        Graham    Male          13500
# 8   C_CND_000009  1/2/2022         Naomi    Male         815000
# 9   C_CND_000010  1/2/2022       Grayson  Female          13500
# 10  C_CND_000011  1/2/2022       Gregory    Male          13500
# 11  C_CND_000012  1/2/2022        Amar'E    Male          13500
# 12  C_CND_000013  1/2/2022       Griffin    Male         885000
# 13  C_CND_000014  1/2/2022      Harrison    Male          13500
# 14  C_CND_000015  1/2/2022        Zainab    Male         722000
# 15  C_CND_000016  1/2/2022          Zara    Male         746000
# 16  C_CND_000017  1/2/2022           Zoe  Female         535000
# 17  C_CND_000018  1/2/2022          Zoey  Female         570000
# 18  C_CND_000019  1/2/2022       Aaliyah    Male         685000
# 19  C_CND_000020  1/2/2022       Abigail    Male         455000
# 20  C_CND_000021  1/2/2022      Adrianna    Male          13500
# 21  C_CND_000022  1/2/2022        Joshua    Male        2500000
# 22  C_CND_000023  1/2/2022        Marcus    Male         585000
# 23  C_CND_000024  1/2/2022        Arthur    Male         920000
# 24  C_CND_000025  1/2/2022        Lizzie    Male         672000
# 25  C_CND_000026  1/2/2022       Florian    Male         801250
# 26  C_CND_000027  1/2/2022     Cassandre  Female         820000
# 27  C_CND_000028  1/2/2022      Syrielle    Male         791000
# 28  C_CND_000029  1/2/2022        Sloane    Male          13500
# 29  C_CND_000030  1/2/2022         Sofia    Male        1020000
#
#                                         Dealer Name     Company  \
# 0               Buddy Storbeck's Diesel Service Inc        Ford
# 1                                  C & M Motors Inc       Dodge
# 2                                       Capitol KIA    Cadillac
# 3                            Chrysler of Tri-Cities      Toyota
# 4                                 Chrysler Plymouth       Acura
# 5                                     Classic Chevy  Mitsubishi
# 6                           Clay Johnson Auto Sales      Toyota
# 7                                         U-Haul CO  Mitsubishi
# 8                              Rabun Used Car Sales   Chevrolet
# 9                              Rabun Used Car Sales        Ford
# 10                                    Race Car Help       Acura
# 11                                    Race Car Help      Nissan
# 12                                 Saab-Belle Dodge     Mercury
# 13                Scrivener Performance Engineering         BMW
# 14              Buddy Storbeck's Diesel Service Inc    Chrysler
# 15                                 C & M Motors Inc      Subaru
# 16                                      Capitol KIA     Hyundai
# 17                           Chrysler of Tri-Cities    Cadillac
# 18                                Chrysler Plymouth      Toyota
# 19                                    Classic Chevy       Honda
# 20                          Clay Johnson Auto Sales      Toyota
# 21                                    Classic Chevy    Infiniti
# 22                               Diehl Motor CO Inc        Audi
# 23                             Star Enterprises Inc     Porsche
# 24                                    Suburban Ford  Volkswagen
# 25                               Tri-State Mack Inc       Dodge
# 26                                        U-Haul CO       Buick
# 27  Progressive Shippers Cooperative Association No    Chrysler
# 28                                    Race Car Help    Chrysler
# 29                   Ryder Truck Rental and Leasing      Saturn
#
#              Model                     Engine Transmission       Color  Price  \
# 0       Expedition  DoubleÂ Overhead Camshaft         Auto       Black  26000
# 1          Durango  DoubleÂ Overhead Camshaft         Auto       Black  19000
# 2         Eldorado          Overhead Camshaft       Manual         Red  31500
# 3           Celica          Overhead Camshaft       Manual  Pale White  14000
# 4               TL  DoubleÂ Overhead Camshaft         Auto         Red  24500
# 5         Diamante          Overhead Camshaft       Manual  Pale White  12000
# 6          Corolla          Overhead Camshaft       Manual  Pale White  14000
# 7           Galant  DoubleÂ Overhead Camshaft         Auto  Pale White  42000
# 8           Malibu          Overhead Camshaft       Manual  Pale White  82000
# 9           Escort  DoubleÂ Overhead Camshaft         Auto  Pale White  15000
# 10              RL          Overhead Camshaft       Manual  Pale White  31000
# 11      Pathfinder  DoubleÂ Overhead Camshaft         Auto  Pale White  46000
# 12   Grand Marquis  DoubleÂ Overhead Camshaft         Auto       Black   9000
# 13            323i  DoubleÂ Overhead Camshaft         Auto  Pale White  15000
# 14   Sebring Coupe          Overhead Camshaft       Manual  Pale White  26000
# 15        Forester          Overhead Camshaft       Manual  Pale White  17000
# 16          Accent          Overhead Camshaft       Manual       Black  18000
# 17        Eldorado  DoubleÂ Overhead Camshaft         Auto  Pale White  31000
# 18    Land Cruiser  DoubleÂ Overhead Camshaft         Auto  Pale White  33000
# 19          Accord  DoubleÂ Overhead Camshaft         Auto  Pale White  21000
# 20         4Runner          Overhead Camshaft       Manual       Black  25000
# 21             I30  DoubleÂ Overhead Camshaft         Auto       Black  21000
# 22              A4          Overhead Camshaft       Manual  Pale White  12000
# 23  Carrera Cabrio  DoubleÂ Overhead Camshaft         Auto  Pale White  18000
# 24           Jetta  DoubleÂ Overhead Camshaft         Auto  Pale White  22000
# 25           Viper  DoubleÂ Overhead Camshaft         Auto  Pale White  31250
# 26           Regal  DoubleÂ Overhead Camshaft         Auto       Black  19000
# 27             LHS          Overhead Camshaft       Manual  Pale White  41000
# 28             LHS          Overhead Camshaft       Manual  Pale White  41000
# 29              LW          Overhead Camshaft       Manual  Pale White  13000
#
#      Dealer_No Body Style    Phone Dealer Region
# 0   06457-3834        SUV  8264678    Middletown
# 1   60504-7114        SUV  6848189        Aurora
# 2   38701-8047  Passenger  7298798    Greenville
# 3   99301-3882        SUV  6257557         Pasco
# 4   53546-9427  Hatchback  7081483    Janesville
# 5   85257-3102  Hatchback  7315216    Scottsdale
# 6   78758-7841  Passenger  7727879        Austin
# 7   78758-7841  Passenger  6206512        Austin
# 8   85257-3102    Hardtop  7194857         Pasco
# 9   85257-3102  Passenger  7836892    Scottsdale
# 10  78758-7841        SUV  7995489        Austin
# 11  78758-7841    Hardtop  7288103         Pasco
# 12  60504-7114        SUV  6842408        Aurora
# 13  38701-8047  Hatchback  7558767    Greenville
# 14  06457-3834      Sedan  7677191    Middletown
# 15  60504-7114  Hatchback  8431908        Aurora
# 16  38701-8047  Hatchback  7814646    Greenville
# 17  99301-3882  Passenger  7456650         Pasco
# 18  53546-9427        SUV  7627010    Janesville
# 19  85257-3102      Sedan  6736704    Scottsdale
# 20  78758-7841      Sedan  7889827        Austin
# 21  85257-3102    Hardtop  6183219        Austin
# 22  06457-3834    Hardtop  8097778    Middletown
# 23  99301-3882  Passenger  7959858         Pasco
# 24  53546-9427  Passenger  8570849    Janesville
# 25  85257-3102        SUV  8520534    Scottsdale
# 26  78758-7841  Passenger  6362556        Austin
# 27  53546-9427  Hatchback  6281210    Janesville
# 28  78758-7841  Hatchback  6292720    Janesville
# 29  06457-3834  Hatchback  7698986    Scottsdale

# %%
carSales.dtypes
# Out:
# Car_id           object
# Date             object
# Customer Name    object
# Gender           object
# Annual Income     int64
# Dealer Name      object
# Company          object
# Model            object
# Engine           object
# Transmission     object
# Color            object
# Price             int64
# Dealer_No        object
# Body Style       object
# Phone             int64
# Dealer Region    object
# dtype: object

# %%
# Remove columns that don't make sense
carSales.drop('Phone', axis=1, inplace=True)
carSales.drop('Car_id', axis=1, inplace=True)
carSales.drop('Dealer_No', axis=1, inplace=True)

carSales.head()
# Out:
#        Date Customer Name Gender  Annual Income  \
# 0  1/2/2022     Geraldine   Male          13500
# 1  1/2/2022           Gia   Male        1480000
# 2  1/2/2022        Gianna   Male        1035000
# 3  1/2/2022       Giselle   Male          13500
# 4  1/2/2022         Grace   Male        1465000
#
#                            Dealer Name   Company       Model  \
# 0  Buddy Storbeck's Diesel Service Inc      Ford  Expedition
# 1                     C & M Motors Inc     Dodge     Durango
# 2                          Capitol KIA  Cadillac    Eldorado
# 3               Chrysler of Tri-Cities    Toyota      Celica
# 4                    Chrysler Plymouth     Acura          TL
#
#                       Engine Transmission       Color  Price Body Style  \
# 0  DoubleÂ Overhead Camshaft         Auto       Black  26000        SUV
# 1  DoubleÂ Overhead Camshaft         Auto       Black  19000        SUV
# 2          Overhead Camshaft       Manual         Red  31500  Passenger
# 3          Overhead Camshaft       Manual  Pale White  14000        SUV
# 4  DoubleÂ Overhead Camshaft         Auto         Red  24500  Hatchback
#
#   Dealer Region
# 0    Middletown
# 1        Aurora
# 2    Greenville
# 3         Pasco
# 4    Janesville

# %%
# Classification - number of Males vs Females
# There are more Males to Females causing a highly imbalanced
genderCount = carSales.groupby('Gender').size()
print(genderCount)
# Out:
# Gender
# Female     5108
# Male      18798
# dtype: int64

# %%
# Correlation refers to the relationship between two variables and how they may or may not change together
# A correlation of -1 shows full negative correlation
# A correlation of 1 shows positive correlation

carSalesCorrelations = pd.get_dummies(carSales, columns = ['Gender', 'Transmission'])
print(carSalesCorrelations)
# Out:
#              Date Customer Name  Annual Income  \
# 0        1/2/2022     Geraldine          13500
# 1        1/2/2022           Gia        1480000
# 2        1/2/2022        Gianna        1035000
# 3        1/2/2022       Giselle          13500
# 4        1/2/2022         Grace        1465000
# ...           ...           ...            ...
# 23901  12/31/2023        Martin          13500
# 23902  12/31/2023         Jimmy         900000
# 23903  12/31/2023          Emma         705000
# 23904  12/31/2023      Victoire          13500
# 23905  12/31/2023       Donovan        1225000
#
#                                Dealer Name    Company       Model  \
# 0      Buddy Storbeck's Diesel Service Inc       Ford  Expedition
# 1                         C & M Motors Inc      Dodge     Durango
# 2                              Capitol KIA   Cadillac    Eldorado
# 3                   Chrysler of Tri-Cities     Toyota      Celica
# 4                        Chrysler Plymouth      Acura          TL
# ...                                    ...        ...         ...
# 23901                     C & M Motors Inc   Plymouth     Voyager
# 23902       Ryder Truck Rental and Leasing  Chevrolet       Prizm
# 23903               Chrysler of Tri-Cities        BMW        328i
# 23904                    Chrysler Plymouth  Chevrolet       Metro
# 23905                      Pars Auto Sales      Lexus       ES300
#
#                           Engine       Color  Price Body Style Dealer Region  \
# 0      DoubleÂ Overhead Camshaft       Black  26000        SUV    Middletown
# 1      DoubleÂ Overhead Camshaft       Black  19000        SUV        Aurora
# 2              Overhead Camshaft         Red  31500  Passenger    Greenville
# 3              Overhead Camshaft  Pale White  14000        SUV         Pasco
# 4      DoubleÂ Overhead Camshaft         Red  24500  Hatchback    Janesville
# ...                          ...         ...    ...        ...           ...
# 23901          Overhead Camshaft         Red  12000  Passenger         Pasco
# 23902  DoubleÂ Overhead Camshaft       Black  16000    Hardtop    Middletown
# 23903          Overhead Camshaft         Red  21000      Sedan    Scottsdale
# 23904  DoubleÂ Overhead Camshaft       Black  31000  Passenger        Austin
# 23905  DoubleÂ Overhead Camshaft  Pale White  27500    Hardtop    Middletown
#
#        Gender_Female  Gender_Male  Transmission_Auto  Transmission_Manual
# 0                  0            1                  1                    0
# 1                  0            1                  1                    0
# 2                  0            1                  0                    1
# 3                  0            1                  0                    1
# 4                  0            1                  1                    0
# ...              ...          ...                ...                  ...
# 23901              0            1                  0                    1
# 23902              1            0                  1                    0
# 23903              0            1                  0                    1
# 23904              0            1                  1                    0
# 23905              0            1                  1                    0
#
# [23906 rows x 15 columns]

# %%
carCorr = carSalesCorrelations.corr(method='pearson')
print(carCorr)
# Out:
#                      Annual Income     Price  Gender_Female  Gender_Male  \
# Annual Income             1.000000  0.012065      -0.054204     0.054204
# Price                     0.012065  1.000000       0.006592    -0.006592
# Gender_Female            -0.054204  0.006592       1.000000    -1.000000
# Gender_Male               0.054204 -0.006592      -1.000000     1.000000
# Transmission_Auto         0.006598  0.011271       0.002647    -0.002647
# Transmission_Manual      -0.006598 -0.011271      -0.002647     0.002647
#
#                      Transmission_Auto  Transmission_Manual
# Annual Income                 0.006598            -0.006598
# Price                         0.011271            -0.011271
# Gender_Female                 0.002647            -0.002647
# Gender_Male                  -0.002647             0.002647
# Transmission_Auto             1.000000            -1.000000
# Transmission_Manual          -1.000000             1.000000

# %%
skews = carSales.skew()
print(skews)
# Out:
# Annual Income    1.739838
# Price            1.466316
# dtype: float64
# /var/folders/0y/6qll5h5d65x7pxcnvtg508k40000gn/T/ipykernel_92176/2956868483.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   skews = carSales.skew()

# %%
from matplotlib import pyplot

# Let's get a better understanding of the distribution of each attribute via histograms (number of observations in each bin)
carSales.hist()
pyplot.show()

# %%
# plot correlation matrix
fig = pyplot.figure()
ax = fig.add_subplot(111)
cax = ax.matshow(carCorr, vmin=-1, vmax=1)
fig.colorbar(cax)
pyplot.show()
